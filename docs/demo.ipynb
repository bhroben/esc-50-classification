# %%
from demo import *

# %%
data=load_audio(audio="output.wav")
spec=make_spec(data)
mel_spec=plot_spec(spec)

# %%
df=classify_spec(spec)
df
# Out:
#                Prediction Time_Run_1 Time_Run_2 Time_Run_3 Time_Run_4  \
# CNN                  frog     27.427     16.359      17.19     15.407
# LSTM       chirping_birds     89.846      50.96      53.22     54.656
# Attention            frog     56.225     54.897     54.751     49.445
#
#           Time_Run_5 Time_Run_6 Time_Run_7 Time_Run_8 Time_Run_9 Time_Run_10
# CNN           15.656     18.743      16.06     15.589     14.286       14.91
# LSTM          54.115      55.41     57.233     84.287    120.723      62.088
# Attention     49.485     53.564     53.295     49.995     50.981      51.137

# %%
fig=plot_bar(df)
